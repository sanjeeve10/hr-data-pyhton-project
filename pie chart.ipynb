# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df= pd.read_csv("C:/Users/prade.LOGEISHVIJAYAN/OneDrive/Desktop/Data Analyst/Batsman.csv")
print (df)
# Out:
#      RunsScored  BallsFaced  BattingPosition Dismissal  Inning   Opposition  \
# 0            12          22                2       LBW       1    Sri Lanka
# 1            37          67                2    Caught       2    Sri Lanka
# 2            25          38                1   Run out       1    Sri Lanka
# 3            54          66                1    Bowled       1    Sri Lanka
# 4            31          46                1       LBW       2    Sri Lanka
# ..          ...         ...              ...       ...     ...          ...
# 203         140         107                3   Stumped       2  West Indies
# 204         157         129                3        NO       1  West Indies
# 205         107         119                3    Bowled       2  West Indies
# 206          16          17                3    Caught       1  West Indies
# 207          33          29                3        NO       2  West Indies
#
#      Year
# 0    2008
# 1    2008
# 2    2008
# ...

# %%
df.head()
# Out:
#    RunsScored  BallsFaced  BattingPosition Dismissal  Inning Opposition  Year
# 0          12          22                2       LBW       1  Sri Lanka  2008
# 1          37          67                2    Caught       2  Sri Lanka  2008
# 2          25          38                1   Run out       1  Sri Lanka  2008
# 3          54          66                1    Bowled       1  Sri Lanka  2008
# 4          31          46                1       LBW       2  Sri Lanka  2008

# %%
plt.figure(figsize=(10, 8))
plt.hist(df["RunsScored"], bins=8, edgecolor="black")
plt.title("Histogram of RunsScored")
plt.xlabel("RunsScored")
plt.ylabel("Frequency")
plt.show()

# %%
x = df['Dismissal'].value_counts()
print (x.index)
# Out:
# Index(['Caught', 'NO', 'Bowled', 'LBW', 'Run out', 'Stumped', 'Hit wicket'], dtype='object', name='Dismissal')

# %%
plt.pie(x,autopct='%0.1f%%',labels=x.index)
plt.show()

# %%
plt.pie(x,autopct='%0.2f%%',labels=x.index,explode=[0,0.20,0,0,0,0,0])
plt.show()

# %%
sns.scatterplot(x=df['RunsScored'], y=df['BallsFaced'])
plt.show()

# %%
sns.scatterplot(x=df['RunsScored'], y=df['BallsFaced'],hue=df["Inning"])
plt.show()

# %%
sns.boxplot(df['RunsScored'])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
sns.boxplot(x=df['RunsScored'], y=df['Inning'])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
sns.boxplot(x=df['Inning'], y=df['RunsScored'],hue=df['Dismissal'])
df.describe()
#statical plot
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %% [markdown]
# palette(Color change)

# %%
sns.boxplot(x=df['Inning'], y=df['RunsScored'],hue=df['Dismissal'],palette=['red','blue','green','yellow','black','pink','purple'])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
#deprecated-going to delete
#CI-confidence internal at 95%
sns.barplot(x=df['Inning'], y=df['RunsScored'],errorbar=None)
# Out:
# <Axes: xlabel='Inning', ylabel='RunsScored'>

# %%
sns.lineplot(x=df['Year'], y =df['RunsScored'])
# Out:
# <Axes: xlabel='Year', ylabel='RunsScored'>

# %%
sns.lineplot(x=df['Year'], y=df['RunsScored'],hue=df['Dismissal'])
# Out:
# <Axes: xlabel='Year', ylabel='RunsScored'>

# %%
sns.lineplot(x=df['Year'], y=df['RunsScored'],hue=df['Dismissal'],palette=['red','blue','green','orange','pink','black','violet'])
# Out:
# <Axes: xlabel='Year', ylabel='RunsScored'>

# %%
sns.violinplot(x=df['Inning'], y=df['RunsScored'])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
sns.stripplot(x=df['Inning'], y=df['RunsScored'])
# Out:
# <Axes: xlabel='Inning', ylabel='RunsScored'>

# %%
#heatplot
numerical_col= df.select_dtypes (include=['int64','float64'])
print (numerical_col)
# Out:
#      RunsScored  BallsFaced  BattingPosition  Inning  Year
# 0            12          22                2       1  2008
# 1            37          67                2       2  2008
# 2            25          38                1       1  2008
# 3            54          66                1       1  2008
# 4            31          46                1       2  2008
# ..          ...         ...              ...     ...   ...
# 203         140         107                3       2  2018
# 204         157         129                3       1  2018
# 205         107         119                3       2  2018
# 206          16          17                3       1  2018
# 207          33          29                3       2  2018
#
# [208 rows x 5 columns]

# %%
categorical_col=df.select_dtypes (include=['object'])
print (categorical_col)
# Out:
#     Dismissal   Opposition
# 0         LBW    Sri Lanka
# 1      Caught    Sri Lanka
# 2     Run out    Sri Lanka
# 3      Bowled    Sri Lanka
# 4         LBW    Sri Lanka
# ..        ...          ...
# 203   Stumped  West Indies
# 204        NO  West Indies
# 205    Bowled  West Indies
# 206    Caught  West Indies
# 207        NO  West Indies
#
# [208 rows x 2 columns]

# %%
#heatplot
cor_matrix=numerical_col.corr()
print (cor_matrix)
# Out:
#                  RunsScored  BallsFaced  BattingPosition    Inning      Year
# RunsScored         1.000000    0.958191        -0.106910  0.081576  0.202092
# BallsFaced         0.958191    1.000000        -0.143914  0.068477  0.148131
# BattingPosition   -0.106910   -0.143914         1.000000 -0.114519 -0.169035
# Inning             0.081576    0.068477        -0.114519  1.000000  0.002244
# Year               0.202092    0.148131        -0.169035  0.002244  1.000000

# %%
sns.heatmap(cor_matrix,)
# Out:
# <Axes: >

# %%
sns.heatmap(cor_matrix,annot=True)
# Out:
# <Axes: >

# %%
#corr matrix
sns.pairplot(cor_matrix)

# %%
sns.plotmap(numerical_col)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 sns.plotmap(numerical_col)
#
# AttributeError: module 'seaborn' has no attribute 'plotmap'
